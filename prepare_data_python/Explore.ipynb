# %%
import pandas as pd
T = pd.read_csv('../data/train.csv.gz')

# %%
# Add more fields

T['DateTime'] = pd.to_datetime(T['DateTime'])
t = T.DateTime
T['dt_year'] = t.dt.year
T['dt_month'] = t.dt.month
T['dt_dayofweek'] = t.dt.dayofweek

# %%
# convert ages to the same unit (days)
ages_day = []
for val in T.AgeuponOutcome:
    if not isinstance(val, str) and np.isnan(val):
        ages_day.append(val)
        continue
    num, unit = val.split()
    num = float(num)
    if 'day' in unit:
        ages_day.append(num)
    elif 'month' in unit:
        ages_day.append(num*30)
    elif 'week' in unit:
        ages_day.append(num*7)
    elif 'year' in unit:
        ages_day.append(num*365)
    else:
        raise ValueError('Unknown unit ' + unit )

T['AgeuponOutcome_days'] = ages_day

# make desexed column and male/female column

#print(T.SexuponOutcome.unique())
sex = T.SexuponOutcome.copy()
sex[np.in1d(sex, ('Neutered Male', 'Intact Male'))] = 'Male'
sex[np.in1d(sex, ('Spayed Female', 'Intact Female'))] = 'Female'
sex[sex == 'Unknown'] = np.nan
#print(sex.unique())
T['sex'] = sex

desexed = T.SexuponOutcome.copy()
desexed[np.in1d(T['SexuponOutcome'], ('Neutered Male','Spayed Female'))] = 'Yes'
desexed[np.in1d(T['SexuponOutcome'], ('Intact Male','Intact Female'))] = 'No'
desexed[T['SexuponOutcome'] == 'Unknown'] = np.nan
#print(desexed.unique())
T['desexed'] = desexed

# %%
# whether it's a mixed breed

T['Breed_is_mix'] = np.array(['mix' in val.lower() for val in T['Breed']])

# %%
# make a unique list of breeds, removing mix words (to assign dog sizes)
breeds = dict(dog=set([]), cat=set([]))
for i,row in T.iterrows():
    val = row['Breed']
    key = row['AnimalType'].lower()
    val = val.lower()
    if val.endswith(' mix'):
        val = val[:-4]
    items = val.split('/')
    for item in items:
        breeds[key].add(item)
# now add size info to dog breeds (see below)

# %%
# Here I add a column giving the size information for each breed of dog. 
# Sizes taken from http://www.dogchannel.com/dog-breeds

s = """affenpinscher  , s
afghan hound   , m 
airedale terrier, m
akita         ,l
alaskan husky  , u
alaskan malamute   ,l
american bulldog    , l
american eskimo     , s 
american foxhound   , l
american pit bull terrier, m
american staffordshire terrier, m
anatol shepherd, l
australian cattle dog, m
australian kelpie, m
australian shepherd,  m
australian terrier,   s
basenji, m
basset hound, m
beagle, m
bearded collie, m
beauceron, l
bedlington terr, s
belgian malinois, l
belgian sheepdog, m
belgian tervuren, m
bernese mountain dog, l
bichon frise, s
black, u
black mouth cur, u
bloodhound, l
blue lacy, u
bluetick hound, m
boerboel, l
border collie, m
border terrier, s
borzoi, l
boston terrier, s
boxer, m
boykin span, m
brittany, m
bruss griffon, s
bull terrier, m
bull terrier miniature, s
bulldog, m
bullmastiff, l
cairn terrier, s
canaan dog, m
cane corso, l
cardigan welsh corgi, m
carolina dog, m
catahoula, u
cavalier span, s
chesa bay retr, m
chihuahua longhair, s
chihuahua shorthair, s
chinese crested, s
chinese sharpei, m
chow chow, m
cocker spaniel, m
collie rough, m
collie smooth, m
dachshund, s
dachshund longhair, s
dachshund wirehair, s
dalmatian, m
doberman pinsch, l
dogo argentino, l
dogue de bordeaux, l
dutch shepherd, m
english bulldog, m
english cocker spaniel, m
english coonhound, u
english foxhound, m
english pointer, u
english setter, m
english shepherd, m
english springer spaniel, m
entlebucher, m
feist, u
field spaniel, m
finnish spitz, m
flat coat retriever, m
french bulldog, s
german pinscher, m
german shepherd, l
german shorthair pointer, m
german wirehaired pointer, m
glen of imaal, m
golden retriever, m
great dane, l
great pyrenees, l
greater swiss mountain dog, l
greyhound, l
harrier, m
havanese, s
hovawart, l
ibizan hound, m
irish setter, l
irish terrier, m
irish wolfhound, l
italian greyhound, s
jack russell terrier, s
japanese chin, s
jindo, u
keeshond, m
kuvasz, l
labrador retriever, m
landseer, u
leonberger, l
lhasa apso, s
lowchen, s
maltese, s
manchester terrier, s
mastiff, l
mexican hairless, u
miniature pinscher, s
miniature poodle, s
miniature schnauzer, s
neapolitan mastiff, l
newfoundland, l
norfolk terrier, s
norwegian elkhound, m
norwich terrier, s
nova scotia duck tolling retriever, m
old english bulldog, l
old english sheepdog, l
otterhound, l
papillon, s
parson russell terrier, s
patterdale terr, s
pbgv, u
pekingese, s
pembroke welsh corgi, m
pharaoh hound, m
picardy sheepdog, u
pit bull, m
plott hound, m
podengo pequeno, u
pointer, m
pomeranian, s
port water dog, m
presa canario, u
pug, s
queensland heeler, m
rat terrier, s
redbone hound, m
rhod ridgeback, l
rottweiler, m
saluki, m
samoyed, m
schipperke, s
schnauzer giant, l
scottish terrier, s
sealyham terr, s
shetland sheepdog, s
shiba inu, s
shih tzu, s
siberian husky, m
silky terrier, s
skye terrier, m
smooth fox terrier, s
soft coated wheaten terrier, s
spanish mastiff, l
spanish water dog, m
spinone italiano, l
st. bernard rough coat, l
st. bernard smooth coat, l
staffordshire, m
standard poodle, m
standard schnauzer, m
swedish vallhund, m
swiss hound, u
tan hound, u
tibetan spaniel, s
tibetan terrier, s
toy fox terrier, s
toy poodle, s
treeing cur, u
treeing tennesse brindle, u
treeing walker coonhound, m
unknown, u
vizsla, l
weimaraner, l
welsh springer spaniel, m
welsh terrier, s
west highland, s
whippet, m
wire hair fox terrier, s
wirehaired pointing griffon, m
yorkshire, s
yorkshire terrier, s"""

size_from_breed = {}
for row in s.split('\n'):
    #print(row)
    breed, size  = row.split(',')
    size_from_breed[breed.strip()] = size.strip()

sizes = []
for i,row in T.iterrows():
    if row['AnimalType'] != 'Dog':
        sizes.append('u')
        continue
    else:
        breed = row['Breed']
    breed = breed.lower()
    if breed.endswith(' mix'):
        breed = breed[:-4]
    breed = breed.split('/')[0]
    if breed in size_from_breed:  
        sizes.append(size_from_breed[breed])
    else:
        sizes.append('u')

T['dogsize'] = sizes

# %%
# Now let's take a look at the table
T
# Out:
#       AnimalID        Name            DateTime      OutcomeType  \
# 0      A671945     Hambone 2014-02-12 18:22:00  Return_to_owner
# 1      A656520       Emily 2013-10-13 12:44:00       Euthanasia
# 2      A686464      Pearce 2015-01-31 12:28:00         Adoption
# 3      A683430         NaN 2014-07-11 19:09:00         Transfer
# 4      A667013         NaN 2013-11-15 12:52:00         Transfer
# 5      A677334        Elsa 2014-04-25 13:04:00         Transfer
# 6      A699218       Jimmy 2015-03-28 13:11:00         Transfer
# 7      A701489         NaN 2015-04-30 17:02:00         Transfer
# 8      A671784        Lucy 2014-02-04 17:17:00         Adoption
# 9      A677747         NaN 2014-05-03 07:48:00         Adoption
# 10     A668402         NaN 2013-12-05 15:50:00         Transfer
# 11     A666320         NaN 2013-11-04 14:48:00         Adoption
# 12     A684601      Rocket 2016-02-03 11:27:00         Adoption
# 13     A704702     Scooter 2015-06-08 16:30:00  Return_to_owner
# 14     A688584     Preston 2015-11-25 15:00:00  Return_to_owner
# 15     A678825      Oliver 2014-07-12 12:10:00         Adoption
# 16     A678050         NaN 2014-05-03 16:15:00         Transfer
# 17     A680028         NaN 2014-06-07 12:54:00         Transfer
# 18     A679010     Chrissy 2014-05-17 11:32:00         Transfer
# 19     A684787        Kuma 2014-07-30 17:34:00  Return_to_owner
# 20     A670658      Anders 2014-01-19 15:03:00         Transfer
# 21     A708812    Munchkin 2015-09-18 15:19:00         Transfer
# 22     A705262     Jamaica 2015-08-15 14:22:00         Adoption
# 23     A665781     Quattro 2013-10-28 16:32:00         Adoption
# 24     A676333     Trigger 2014-04-09 17:44:00  Return_to_owner
# 25     A712750       Olive 2015-10-03 15:44:00         Transfer
# 26     A718832         Nia 2016-01-15 17:31:00         Adoption
# 27     A698777       Chloe 2015-03-25 18:50:00         Adoption
# 28     A715348     Cymbale 2015-11-21 13:01:00         Adoption
# 29     A708666         Jax 2015-07-30 14:30:00  Return_to_owner
# ...        ...         ...                 ...              ...
# 26699  A676460       Mario 2014-04-21 14:01:00       Euthanasia
# 26700  A704999        Lion 2015-06-15 19:28:00  Return_to_owner
# 26701  A678842        Ella 2014-06-15 17:41:00         Transfer
# 26702  A713637         NaN 2015-10-11 09:42:00             Died
# 26703  A716670      Mowmow 2015-12-04 12:22:00         Transfer
# 26704  A716223       Alice 2015-11-17 17:17:00         Transfer
# 26705  A662498       Grace 2013-10-19 15:34:00         Transfer
# 26706  A689942        Zoey 2014-10-19 13:29:00         Adoption
# 26707  A682690         NaN 2014-07-01 17:06:00       Euthanasia
# 26708  A666920      Herbie 2013-11-13 17:32:00         Transfer
# 26709  A714386         NaN 2015-10-24 00:00:00         Adoption
# 26710  A692622      Bonnie 2014-11-24 17:21:00         Transfer
# 26711  A666284       Sonja 2013-10-30 18:32:00         Transfer
# 26712  A535277      Merlin 2015-04-20 16:04:00  Return_to_owner
# 26713  A671169         NaN 2014-01-20 17:37:00       Euthanasia
# 26714  A679031        Pete 2014-05-31 16:11:00         Adoption
# 26715  A708833        Luna 2015-08-05 17:03:00         Adoption
# 26716  A697158         Max 2015-05-02 21:04:00         Adoption
# 26717  A519949       Bella 2014-06-30 17:34:00  Return_to_owner
# 26718  A701044         NaN 2015-04-28 14:26:00         Adoption
# 26719  A707871         NaN 2015-07-20 09:00:00         Transfer
# 26720  A704405     Brownie 2015-07-18 14:08:00         Adoption
# 26721  A662019  Green Bean 2014-07-17 09:43:00         Adoption
# 26722  A687056         NaN 2014-08-31 09:00:00         Transfer
# 26723  A716997        Zeus 2016-01-29 18:52:00         Adoption
# 26724  A702446         NaN 2015-05-14 11:56:00         Transfer
# 26725  A718934         NaN 2016-01-20 18:59:00         Transfer
# 26726  A698128        Zeus 2015-03-09 13:33:00         Adoption
# 26727  A677478         NaN 2014-04-27 12:22:00         Transfer
# 26728  A706629         NaN 2015-07-02 09:00:00         Transfer
#
#       OutcomeSubtype AnimalType SexuponOutcome AgeuponOutcome  \
# 0                NaN        Dog  Neutered Male         1 year
# 1          Suffering        Cat  Spayed Female         1 year
# 2             Foster        Dog  Neutered Male        2 years
# 3            Partner        Cat    Intact Male        3 weeks
# 4            Partner        Dog  Neutered Male        2 years
# 5            Partner        Dog  Intact Female        1 month
# 6            Partner        Cat    Intact Male        3 weeks
# 7            Partner        Cat        Unknown        3 weeks
# 8                NaN        Dog  Spayed Female       5 months
# 9            Offsite        Dog  Spayed Female         1 year
# 10              SCRP        Cat        Unknown        2 years
# 11               NaN        Dog  Spayed Female        2 years
# 12            Foster        Dog  Neutered Male        4 years
# 13               NaN        Dog  Neutered Male        2 years
# 14               NaN        Dog  Neutered Male         1 year
# 15            Foster        Cat  Neutered Male       3 months
# 16           Partner        Cat    Intact Male        3 weeks
# 17           Partner        Dog  Intact Female        2 weeks
# 18           Partner        Cat  Intact Female        2 years
# 19               NaN        Dog  Neutered Male         1 year
# 20           Partner        Dog    Intact Male       2 months
# 21           Partner        Cat  Spayed Female         1 year
# 22               NaN        Dog  Spayed Female        2 years
# 23               NaN        Dog  Neutered Male      10 months
# 24               NaN        Dog  Neutered Male       2 months
# 25           Partner        Cat  Intact Female        1 month
# 26               NaN        Dog  Spayed Female       6 months
# 27               NaN        Dog  Spayed Female        5 years
# 28               NaN        Cat  Spayed Female       2 months
# 29               NaN        Cat  Neutered Male        7 years
# ...              ...        ...            ...            ...
# 26699       Behavior        Dog  Neutered Male        2 years
# 26700            NaN        Dog    Intact Male      10 months
# 26701        Partner        Dog  Intact Female      11 months
# 26702      In Kennel        Cat  Spayed Female        2 years
# 26703        Partner        Cat  Neutered Male        6 years
# 26704        Partner        Cat  Intact Female        4 weeks
# 26705        Partner        Cat  Intact Female       2 months
# 26706            NaN        Cat  Spayed Female       2 months
# 26707      Suffering        Cat        Unknown         1 year
# 26708        Partner        Dog  Neutered Male        2 years
# 26709            NaN        Dog  Spayed Female        1 month
# 26710        Partner        Dog  Intact Female        1 month
# 26711        Partner        Dog  Intact Female         1 year
# 26712            NaN        Dog  Neutered Male       12 years
# 26713      Suffering        Cat  Intact Female       18 years
# 26714            NaN        Cat  Spayed Female       2 months
# 26715            NaN        Dog  Spayed Female       2 months
# 26716        Offsite        Dog  Neutered Male       2 months
# 26717            NaN        Dog  Spayed Female        9 years
# 26718            NaN        Dog  Neutered Male       2 months
# 26719           SCRP        Cat        Unknown        2 years
# 26720            NaN        Cat  Spayed Female       2 months
# 26721         Foster        Cat  Spayed Female        5 years
# 26722           SCRP        Cat    Intact Male       5 months
# 26723            NaN        Dog  Neutered Male        6 years
# 26724        Partner        Cat    Intact Male        1 month
# 26725           SCRP        Cat  Spayed Female       3 months
# 26726            NaN        Dog  Neutered Male        4 years
# 26727        Partner        Cat    Intact Male        4 weeks
# 26728           SCRP        Cat    Intact Male         1 year
#
#                                        Breed                Color  dt_year  \
# 0                      Shetland Sheepdog Mix          Brown/White     2014
# 1                     Domestic Shorthair Mix          Cream Tabby     2013
# 2                               Pit Bull Mix           Blue/White     2015
# 3                     Domestic Shorthair Mix           Blue Cream     2014
# 4                Lhasa Apso/Miniature Poodle                  Tan     2013
# 5          Cairn Terrier/Chihuahua Shorthair            Black/Tan     2014
# 6                     Domestic Shorthair Mix           Blue Tabby     2015
# 7                     Domestic Shorthair Mix          Brown Tabby     2015
# 8              American Pit Bull Terrier Mix            Red/White     2014
# 9                              Cairn Terrier                White     2014
# 10                    Domestic Shorthair Mix                Black     2013
# 11                   Miniature Schnauzer Mix               Silver     2013
# 12                              Pit Bull Mix                Brown     2016
# 13                     Yorkshire Terrier Mix            Black/Red     2015
# 14                        Great Pyrenees Mix          White/Cream     2015
# 15                    Domestic Shorthair Mix   Orange Tabby/White     2014
# 16                    Domestic Shorthair Mix          Brown Tabby     2014
# 17                              Pit Bull Mix          Brown/White     2014
# 18                                Angora Mix                White     2014
# 19                   Flat Coat Retriever Mix                Black     2014
# 20                     Queensland Heeler Mix          Black/White     2014
# 21                    Domestic Shorthair Mix                White     2015
# 22                         Plott Hound/Boxer  Brown Brindle/White     2015
# 23                       German Shepherd Mix          Brown/White     2013
# 24                       German Shepherd Mix          Black/Brown     2014
# 25                    Domestic Shorthair Mix         Orange Tabby     2015
# 26        American Staffordshire Terrier Mix      Chocolate/White     2016
# 27                   Chihuahua Shorthair Mix            White/Tan     2015
# 28                    Domestic Shorthair Mix    Cream Tabby/White     2015
# 29                          Russian Blue Mix                 Blue     2015
# ...                                      ...                  ...      ...
# 26699          American Pit Bull Terrier Mix          White/Black     2014
# 26700         Great Pyrenees/Anatol Shepherd            Tan/Cream     2015
# 26701               Jack Russell Terrier Mix          White/Black     2014
# 26702                            Siamese Mix           Lynx Point     2015
# 26703                  Domestic Longhair Mix           Seal Point     2015
# 26704                 Domestic Shorthair Mix          White/Black     2015
# 26705                 Domestic Shorthair Mix               Tortie     2013
# 26706                 Domestic Shorthair Mix                Black     2014
# 26707                 Domestic Shorthair Mix          Brown Tabby     2014
# 26708                Chihuahua Shorthair Mix          White/Brown     2013
# 26709                Chihuahua Shorthair Mix           Sable/Buff     2015
# 26710  Chihuahua Shorthair/Yorkshire Terrier          Brown/Black     2014
# 26711               Cocker Spaniel/Dachshund                 Buff     2013
# 26712                            Rat Terrier        Chocolate/Tan     2015
# 26713                  Domestic Longhair Mix               Tortie     2014
# 26714                 Domestic Shorthair Mix         Orange Tabby     2014
# 26715                            Pointer Mix          Black/White     2015
# 26716                       Newfoundland Mix          White/Black     2015
# 26717                        Bullmastiff Mix                Black     2014
# 26718         Siberian Husky/German Shepherd       Black/Tricolor     2015
# 26719                 Domestic Shorthair Mix    Brown Tabby/White     2015
# 26720                 Domestic Shorthair Mix          Brown Tabby     2015
# 26721                 Domestic Shorthair Mix                Black     2014
# 26722                 Domestic Shorthair Mix         Orange Tabby     2014
# 26723                      Staffordshire Mix           Blue/White     2016
# 26724                 Domestic Shorthair Mix    Brown Tabby/White     2015
# 26725                 Domestic Shorthair Mix          Brown Tabby     2016
# 26726                Old English Bulldog Mix            White/Tan     2015
# 26727                 Domestic Shorthair Mix                Black     2014
# 26728                 Domestic Shorthair Mix    Brown Tabby/White     2015
#
#        dt_month  dt_dayofweek  AgeuponOutcome_days     sex desexed  \
# 0             2             2                365.0    Male     Yes
# 1            10             6                365.0  Female     Yes
# 2             1             5                730.0    Male     Yes
# 3             7             4                 21.0    Male      No
# 4            11             4                730.0    Male     Yes
# 5             4             4                 30.0  Female      No
# 6             3             5                 21.0    Male      No
# 7             4             3                 21.0     NaN     NaN
# 8             2             1                150.0  Female     Yes
# 9             5             5                365.0  Female     Yes
# 10           12             3                730.0     NaN     NaN
# 11           11             0                730.0  Female     Yes
# 12            2             2               1460.0    Male     Yes
# 13            6             0                730.0    Male     Yes
# 14           11             2                365.0    Male     Yes
# 15            7             5                 90.0    Male     Yes
# 16            5             5                 21.0    Male      No
# 17            6             5                 14.0  Female      No
# 18            5             5                730.0  Female      No
# 19            7             2                365.0    Male     Yes
# 20            1             6                 60.0    Male      No
# 21            9             4                365.0  Female     Yes
# 22            8             5                730.0  Female     Yes
# 23           10             0                300.0    Male     Yes
# 24            4             2                 60.0    Male     Yes
# 25           10             5                 30.0  Female      No
# 26            1             4                180.0  Female     Yes
# 27            3             2               1825.0  Female     Yes
# 28           11             5                 60.0  Female     Yes
# 29            7             3               2555.0    Male     Yes
# ...         ...           ...                  ...     ...     ...
# 26699         4             0                730.0    Male     Yes
# 26700         6             0                300.0    Male      No
# 26701         6             6                330.0  Female      No
# 26702        10             6                730.0  Female     Yes
# 26703        12             4               2190.0    Male     Yes
# 26704        11             1                 28.0  Female      No
# 26705        10             5                 60.0  Female      No
# 26706        10             6                 60.0  Female     Yes
# 26707         7             1                365.0     NaN     NaN
# 26708        11             2                730.0    Male     Yes
# 26709        10             5                 30.0  Female     Yes
# 26710        11             0                 30.0  Female      No
# 26711        10             2                365.0  Female      No
# 26712         4             0               4380.0    Male     Yes
# 26713         1             0               6570.0  Female      No
# 26714         5             5                 60.0  Female     Yes
# 26715         8             2                 60.0  Female     Yes
# 26716         5             5                 60.0    Male     Yes
# 26717         6             0               3285.0  Female     Yes
# 26718         4             1                 60.0    Male     Yes
# 26719         7             0                730.0     NaN     NaN
# 26720         7             5                 60.0  Female     Yes
# 26721         7             3               1825.0  Female     Yes
# 26722         8             6                150.0    Male      No
# 26723         1             4               2190.0    Male     Yes
# 26724         5             3                 30.0    Male      No
# 26725         1             2                 90.0  Female     Yes
# 26726         3             0               1460.0    Male     Yes
# 26727         4             6                 28.0    Male      No
# 26728         7             3                365.0    Male      No
#
#       Breed_is_mix dogsize
# 0             True       s
# 1             True       u
# 2             True       m
# 3             True       u
# 4            False       s
# 5            False       s
# 6             True       u
# 7             True       u
# 8             True       m
# 9            False       s
# 10            True       u
# 11            True       s
# 12            True       m
# 13            True       s
# 14            True       l
# 15            True       u
# 16            True       u
# 17            True       m
# 18            True       u
# 19            True       m
# 20            True       m
# 21            True       u
# 22           False       m
# 23            True       l
# 24            True       l
# 25            True       u
# 26            True       m
# 27            True       s
# 28            True       u
# 29            True       u
# ...            ...     ...
# 26699         True       m
# 26700        False       l
# 26701         True       s
# 26702         True       u
# 26703         True       u
# 26704         True       u
# 26705         True       u
# 26706         True       u
# 26707         True       u
# 26708         True       s
# 26709         True       s
# 26710        False       s
# 26711        False       m
# 26712        False       s
# 26713         True       u
# 26714         True       u
# 26715         True       m
# 26716         True       l
# 26717         True       l
# 26718        False       m
# 26719         True       u
# 26720         True       u
# 26721         True       u
# 26722         True       u
# 26723         True       m
# 26724         True       u
# 26725         True       u
# 26726         True       l
# 26727         True       u
# 26728         True       u
#
# [26729 rows x 18 columns]

# %%
T.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26729 entries, 0 to 26728
# Data columns (total 18 columns):
# AnimalID               26729 non-null object
# Name                   19038 non-null object
# DateTime               26729 non-null datetime64[ns]
# OutcomeType            26729 non-null object
# OutcomeSubtype         13117 non-null object
# AnimalType             26729 non-null object
# SexuponOutcome         26728 non-null object
# AgeuponOutcome         26711 non-null object
# Breed                  26729 non-null object
# Color                  26729 non-null object
# dt_year                26729 non-null int64
# dt_month               26729 non-null int64
# dt_dayofweek           26729 non-null int64
# AgeuponOutcome_days    26711 non-null float64
# sex                    25635 non-null object
# desexed                25635 non-null object
# Breed_is_mix           26729 non-null bool
# dogsize                26729 non-null object
# dtypes: bool(1), datetime64[ns](1), float64(1), int64(3), object(12)
# memory usage: 3.5+ MB

# %%
for name in T.columns:
    print('\n### ' + name + '\n', T[name].describe(), sep='')
# Out:
# ### AnimalID
# count       26729
# unique      26729
# top       A694918
# freq            1
# Name: AnimalID, dtype: object
#
# ### Name
# count     19038
# unique     6374
# top         Max
# freq        136
# Name: Name, dtype: object
#
# ### DateTime
# count                   26729
# unique                  22918
# top       2015-08-11 00:00:00
# freq                       19
# first     2013-10-01 09:31:00
# last      2016-02-21 19:17:00
# Name: DateTime, dtype: object
#
# ### OutcomeType
# count        26729
# unique           5
# top       Adoption
# freq         10769
# Name: OutcomeType, dtype: object
#
# ### OutcomeSubtype
# count       13117
# unique         16
# top       Partner
# freq         7816
# Name: OutcomeSubtype, dtype: object
#
# ### AnimalType
# count     26729
# unique        2
# top         Dog
# freq      15595
# Name: AnimalType, dtype: object
#
# ### SexuponOutcome
# count             26728
# unique                5
# top       Neutered Male
# freq               9779
# Name: SexuponOutcome, dtype: object
#
# ### AgeuponOutcome
# count      26711
# unique        44
# top       1 year
# freq        3969
# Name: AgeuponOutcome, dtype: object
#
# ### Breed
# count                      26729
# unique                      1380
# top       Domestic Shorthair Mix
# freq                        8810
# Name: Breed, dtype: object
#
# ### Color
# count           26729
# unique            366
# top       Black/White
# freq             2824
# Name: Color, dtype: object
#
# ### dt_year
# count    26729.000000
# mean      2014.430731
# std          0.741408
# min       2013.000000
# 25%       2014.000000
# 50%       2014.000000
# 75%       2015.000000
# max       2016.000000
# Name: dt_year, dtype: float64
#
# ### dt_month
# count    26729.000000
# mean         6.925736
# std          3.495869
# min          1.000000
# 25%          4.000000
# 50%          7.000000
# 75%         10.000000
# max         12.000000
# Name: dt_month, dtype: float64
#
# ### dt_dayofweek
# count    26729.000000
# mean         3.106364
# std          2.046001
# min          0.000000
# 25%          1.000000
# 50%          3.000000
# 75%          5.000000
# max          6.000000
# Name: dt_dayofweek, dtype: float64
#
# ### AgeuponOutcome_days
# count    26711.000000
# mean       794.130770
# std       1082.830232
# min          0.000000
# 25%               NaN
# 50%               NaN
# 75%               NaN
# max       7300.000000
# Name: AgeuponOutcome_days, dtype: float64
#
# ### sex
# count     25635
# unique        2
# top        Male
# freq      13304
# Name: sex, dtype: object
#
# ### desexed
# count     25635
# unique        2
# top         Yes
# freq      18599
# Name: desexed, dtype: object
#
# ### Breed_is_mix
# count     26729
# unique        2
# top        True
# freq      22298
# Name: Breed_is_mix, dtype: object
#
# ### dogsize
# count     26729
# unique        4
# top           u
# freq      11612
# Name: dogsize, dtype: object
# /Users/ncrighton/anaconda/envs/py3/lib/python3.5/site-packages/numpy/lib/function_base.py:3823: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)

# %%
# use a pivot table to examine which parameters have the biggest effect on the outcome. 
from pivottablejs import pivot_ui
pivot_ui(T)
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="pivottablejs.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# The outcome depends strongly on the age (AgeuponOutcome_days), whether the animal has been desexed, and on the animal type (dog or cat). It doesn't depend much on the sex (male/female), or on the dog size. There doesn't seem to be a big change in outcome with day of the week, month or year of the outcome.

# %% [markdown]
# Below are plots showing how the outcome changes with the animal type (dog or cat), with the desexed status (intact vs spayed/neutered) and the age of the animal, which seem to have the biggest influence on the outcome. They are all screenshots from the pivottablejs app above; it was simpler to just take these screenshots instead of working out how to reproduce the plots in pandas.
#
# ## Outcome vs type
#
# The outcome vs the animal type. Cats are much more likely to be transferred than dogs, and less likely to be returned to their owner.
#
# <img src="img/outcome_vs_type.png" style="width: 700px"/>
#
# ## Outcome vs age
#
# There are two plots here - the first shows the total number of animals vs age, to give you a feel for the age distribution. The second shows the fraction of animals falling into each outcome vs age. Animals less than a month old are usually transferred. Animals older than one month are typically transferred, adopted, or returned to their owner. As the animals get older (> 3650 days, which is > 10 years), they are more likely to be euthanased.
#
# <img src="img/outcome_vs_age_tot.png" style="width: 700px"/>
# <img src="img/outcome_vs_age.png" style="width: 700px"/>
#
# ## Outcome vs desexed
#
# This shows the outcome vs whether the dog or cat has been desexed. Desexed animals are more likely to be adopted or returned to their owner. Non-desexed animals are more likely to be transferred or euthanased.
#
# <img src="img/outcome_vs_desexed.png" style="width: 700px"/>
#
#
# ## Outcome vs size
#
# There isn't much change in outcome with dog size ('u' here means unknown - all the cats have size=u). Maybe medium-sized dogs are more likely to be euthanased?
#
# <img src="img/outcome_vs_size.png" style="width: 700px"/>

# %%
# write out the new training table which has all the new columns added.
T.to_csv('../data/train_prep.csv')
